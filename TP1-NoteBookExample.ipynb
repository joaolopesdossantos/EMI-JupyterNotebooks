# %% [markdown]
# # TP1:  Exemplo de Notebook
#
# ## Eletromagnetismo I  FIS1017: 2022-23
#
# Um notebook é composto de vários tipos de células. Esta é uma célula **Markdown** destinada a escrever texto e permite algumas formatações simples, incluíndo a escrita de equações. Clicando duas vezes dentro de um célula vemos o texto tal como foi digitado. Se *executarmos* uma célula, fazendo SHIFT+ENTER, vemos o seu conteúdo formatado, se for uma célula **markdown**, ou o código python executado se for uma célula **code** .
#
# Vale a pena conhecer algumas maneiras de formatar texto em células *markdown*.
#
# Para escrever um título basta preceder o texto do caracter "#" uma ou várias vezes:
#
# # Headings
#
# ## Heading 2
#
# ### Heading 4
#
# Para fazer uma lista temos várias possibilidades:
#
# - começar a linha com hífen "-" ou  com  "\*" seguido de espaço.
#  - segundo item
# - terceiro item
#    - aumentar a indentação gera uma sublista
#
# Podemos fazer listas numeradas começando com número seguido de "." :
#
#  1. Lista numerada
#  - segunda linha
#  - terceira linha
#    1. mais linhas
#    -  mais linhas
#
# Para mais informação sobre a maneira de marcar o texto em células **markdown** consultar [Markdown in Jupyter notebook](https://www.datacamp.com/community/tutorials/markdown-in-jupyter-notebook?utm_source=adwords_ppc&utm_campaignid=9942305733&utm_adgroupid=100189364546&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=&utm_creative=229765585186&utm_targetid=dsa-929501846124&utm_loc_interest_ms=&utm_loc_physical_ms=1011759&gclid=EAIaIQobChMI9vSA4tC16gIVmKSyCh1iOwoGEAAYASAAEgKnkPD_BwE)

# %% [markdown]
# ### Células de código
#
# O outro tipo de células contém código na linguagem especificado para o notebook (**Python**) no nosso caso. A célula seguinte é um exemplo. Para executar o código podemos clicar em **Run** na barra abaixo do menu ou *Shift+Enter*.

# %%
a=3+12
print(a)
# Out:
# 15

# %%
a
# Out:
# 15

# %% [markdown]
# ### Equações
#
# Para escrever símbolos ou  equações matemáticas o Jupyter Notebook  usa LaTeX. No pesente contexto o importante é notar que o notebook interpreta como comando latex o que estiver entre os sinais $\$$ e $\$$. A célul*a* seguinte tem vários exemplos, que se auto explicam. Clica duas vezes para veres como foram digitadas estas equações. *a*

# %% [markdown]
# $a$
#
# $a^{-25}$
#
# $\sqrt{1-x^2}$
#
# $\frac{1}{\sqrt{1-x^2}}$
#
# $a_1,a_2,a_3,\dots,a_n\dots$
#
# $\int_{0}^{\infty}\sin(x)dx$
#
# $\alpha,\beta,\gamma,\delta,\Delta$
#
# $$\frac{1}{\sqrt{1-x^2}}$$
#
# $\Gamma$
#
# $$
# v=\frac{dx}{dt}
# $$
#
# $\sum_{i=1}^{10} x_i$

# %% [markdown]
# Se escrevermos um equação em LaTeX entre dois pares de sinais $\$$ \begin{equation}\dots\frac{1}{\sqrt{1-x^2}}\end{equation} ela aparece numa linha separada.
#
#
# $\intop_{a}^{b}dx\cos(x)$

# %% [markdown]
# Para uma iniciação à notação matemática do LaTeX ver esta [cábula (cheatSheet)](https://users.dickinson.edu/~richesod/latex/latexcheatsheet.pdf) de duas páginas, criada por Dave Richeson do Dickinson College, que contém o código latex de qualquer equação que alguma vez precises.

# %% [markdown]
# ![3D_deslocamento.png](attachment:3D_deslocamento.png)

# %% [markdown]
# ### Imagens
# ![avecb.png](attachment:avecb.png "Exemplo")
#
# Um notebook pode incluir imagens lidas de um ficheiro,inseridas nuam célula *markdown* como esta.
#
#    Esta imagem foi inserida usando no menu **Edit** a linha **insert image**. Deste modo o ficheiro que contém a  imagem fica incorporado no notebook. Infelizmente não conheço nenhuma maneira de alterar o tamanho com que a imagem é mostrada, a não ser alterando o ficheiro original da Figura.
#
#    Para especificar o tamanho da figura no notebook,temos de usar código html, mas o ficheiro da imagem tem de existir no diretório indicado.  <img src=Figuras/avecb.png width=100/> Neste caso tem de existir na pasta onde está o  notebook uma pasta "Figuras" que contém o ficheiro avecb.png.

# %% [markdown]
# ### Numpy e Matplotlib
#
# Para poder usar todas as funcionalidades que a comunidade Pyhton criou para trabalho científico (funções matemáticas, vectores, gráficos) é necessário carregar alguns módulos importantes do Python. A célula seguinte faz essa incialização (é a primeira dos meus notebooks), e a seguir ilustramos algumas funcionalidades. Para usar mais extensamente convém aprender Python.

# %%
# %matplotlib inline                         
                                           # comando que faz com que as figuras
                                           # fiquem embebidas no notebook
import numpy as np                         # modulo numérico, essencial para trabalho 
                                           # cientifico; chamado com nome abreviado np
from matplotlib.pylab import *             # módulo de gráficos.

# %%
np.cos(np.pi/4)                             # funcao cos do módulo numpy 
                                            # importado com nome np
# Out:
# 0.7071067811865476

# %%
np.pi
# Out:
# 3.141592653589793

# %%
np.exp(np.log(2))                                # função exponencial do módulo numpy
# Out:
# 2.0

# %%
x=np.arange(.1,4,1)
print(x)
# Out:
# [0.1 1.1 2.1 3.1]

# %%
# outro modo de gerar coordenadas. Vês a diferença?
x=np.linspace(0,4,40)
print(x)
# Out:
# [0.         0.1025641  0.20512821 0.30769231 0.41025641 0.51282051
#  0.61538462 0.71794872 0.82051282 0.92307692 1.02564103 1.12820513
#  1.23076923 1.33333333 1.43589744 1.53846154 1.64102564 1.74358974
#  1.84615385 1.94871795 2.05128205 2.15384615 2.25641026 2.35897436
#  2.46153846 2.56410256 2.66666667 2.76923077 2.87179487 2.97435897
#  3.07692308 3.17948718 3.28205128 3.38461538 3.48717949 3.58974359
#  3.69230769 3.79487179 3.8974359  4.        ]

# %%
x= np.arange(0.1,10,.25)               # lista de abcissas de 0 a 9.9 por intervalos de 0.1
y = np.sin(x)                       # lista de ordenadas; a função sin é aplicada a cada elemento da lista x
plot(x,y)                     # plot mais simples, duas listas de valores de x e y

# %%
plot(y)

# %%
# impressão formatada de lista
# a função print tem uma string de formatação; os sinais % são "placeholders" onde
# são inseridos oa valores da variaveis e 5.3f especifica um campo de 5 caracteres para escrever uma variável 
# float com 3 casas decimais. '\t' insere um tab.

for i in range(40):
    print ('%5.3f\t%5.3f' %(x[i],y[i]) )
# Out:
# 0.000	0.100
# 0.103	0.343
# 0.205	0.565
# 0.308	0.751
# 0.410	0.891
# 0.513	0.976
# 0.615	1.000
# 0.718	0.961
# 0.821	0.863
# 0.923	0.711
# 1.026	0.516
# 1.128	0.287
# 1.231	0.042
# 1.333	-0.207
# 1.436	-0.443
# 1.538	-0.651
# 1.641	-0.818
# 1.744	-0.935
# 1.846	-0.994
# 1.949	-0.991
# 2.051	-0.926
# 2.154	-0.804
# 2.256	-0.631
# 2.359	-0.420
# 2.462	-0.182
# 2.564	0.067
# 2.667	0.312
# 2.769	0.537
# 2.872	0.729
# 2.974	0.876
# 3.077	0.968
# 3.179	1.000
# 3.282	0.970
# 3.385	0.879
# 3.487	0.734
# 3.590	0.544
# 3.692	0.319
# 3.795	0.075
# 3.897	-0.174
# 4.000	-0.413

# %%
print (np.sin(x))

# %%
# Um gráfico mais trabalhado
xlabel("x", fontsize=20)
ylabel ("sin(x)", fontsize=20)
grid(True)
title("Gráfico de Sin(x)", fontsize=20)
plot(x,y)

# %% [markdown]
# Existem excelentes   [tutoriais](https://matplotlib.org/3.1.1/tutorials/index.html) na documentação do Matplotlib. Para começar ver [pyplot tutorial](https://matplotlib.org/3.1.1/tutorials/introductory/pyplot.html#sphx-glr-tutorials-introductory-pyplot-py).
#
# O Jupyter notebook é uma ferramenta de enorme valor num curso científico. Podes usá-lo como calculadora, vizualizar e analisar dados. Na UC de *Introdução à programação*, aprenderás **Python** e poderás tirar partido da interactividade do notebook.

# %%
# exemplo de calculadora. O raio de Bohr em unidades SI
hbar=1.055e-34              # const Planck reduzida
e=1.6e-19                   # carga do eletrão
epsilon0=8.854e-12          # permitividade electrica vazio 
me=9.109e-31                # massa do electrão
a0=(4*np.pi*epsilon0)*hbar**2/(me*e**2)
print(a0)
# Out:
# 5.310600518635381e-11

# %% [markdown]
# ## Exercícios

# %% [markdown]
# ###  1. Criação de um Notebook

# %% [markdown]
# Cria um novo notebook com o seguinte conteúdo mínimo:
#
# - Um título;
#
# - uma célula de texto;
#
# - Uma célula com três equações;
#
# - Uma célula com um link para um site da tua escolha;
#
# - uma  impressão (no notebook) de uma tabela da função $\exp(-x^2)$ para $x \in [-2,2] $;
#
# - um gráfico desta mesma função.

# %% [markdown]
# ###  Questões
# #### 2. Eletromagnetismo e Gravitação
# Uma maneira padrão de comparar as intensidades da interação eletromagnética e gravítica é calcular a razão das forças gravíticas e eletricas entre duas partículas elementares, por exempo, dois electrões. Começa por definir os valores SI das constantes fundamentais como por exemplo,

# %%
G = 6.67430E-11

# %% [markdown]
# Depois determina em termos das constantes universais  a razão indicada e comenta o resultado.

# %% [markdown]
# ### Gráfico de Campo
# Pretende-se representar o valor do campo elétrico criado por duas cargas $q_1=2\mu  C$ e $q_2=-2\mu C$ distantes de  $d=1$ m no eixo $Ox$ ao longo da linha que bissecta o segmento que une as duas cargas. Escreve uma função que calcule o valor desse campo e representa-o graficamente.
